# %% [markdown]
# <a href="https://colab.research.google.com/github/MaksChojniak/RL-Training/blob/google-colab/InitializationTest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # clone repository from github

# %%
# !git clone https://github.com/MaksChojniak/RL-Training.git
# Out:
# fatal: destination path 'RL-Training' already exists and is not an empty directory.

# %% [markdown]
# # install libraries for RL Training

# %%
# !pip install numpy

# %%
# !pip3 install torch torchvision --index-url https://download.pytorch.org/whl/cu126
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu126
# ...

# %%
import torch as t

print(t.__version__)
print("CUDA available:", t.cuda.is_available())
print("Device count:", t.cuda.device_count())
print("Current device:", t.cuda.current_device())
print("Device name:", t.cuda.get_device_name(0))
# Out:
# 2.8.0+cu126
# CUDA available: True
# Device count: 1
# Current device: 0
# Device name: Tesla T4

# %% [markdown]
# # run code from github repository

# %%
# !python ./RL-Training/main.py
# Out:
# 2.8.0+cu126
# CUDA available: True
# Device count: 1
# Current device: 0
# Device name: Tesla T4
